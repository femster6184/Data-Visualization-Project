# %%
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)
from datetime import datetime as dt
import json
from pathlib import Path

# %%
moon_air_quality_df = pd.read_csv('CSVs/Cloud_Cover.csv')
moon_air_quality_df.head()
# Out:
#    cloud  visibility_km  visibility_miles  air_quality
# 0      0           10.0                 6          7.9
# 1     75           10.0                 6         28.2
# 2     25           10.0                 6          6.4
# 3      6           10.0                 6          0.5
# 4     75           10.0                 6        139.6

# %%
moon_air_quality_df.dtypes
# Out:
# cloud                 int64
# visibility_km       float64
# visibility_miles      int64
# air_quality         float64
# dtype: object

# %%
moon_air_quality_df=moon_air_quality_df.rename(columns={"air_quality_PM2": "air_quality"})

moon_air_quality_df.head()
# Out:
#    cloud  visibility_km  visibility_miles  air_quality
# 0      0           10.0                 6          7.9
# 1     75           10.0                 6         28.2
# 2     25           10.0                 6          6.4
# 3      6           10.0                 6          0.5
# 4     75           10.0                 6        139.6

# %%
moon_air_cleaned=moon_air_quality_df[["air_quality","moon_illumination"]]
moon_air_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 moon_air_cleaned=moon_air_quality_df[["air_quality","moon_illumination"]]
#       2 moon_air_cleaned.head()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
# ...

# %%
moon_air_cleaned.to_csv("CSVs/moon_vs_air_quality.csv", index=False)

# %%
weather_repository_df = pd.read_csv('CSVs/GlobalWeatherRepository_full_data.csv')

# %%
weather_repository_cleaned=weather_repository_df[["latitude", "longitude", "temperature_fahrenheit", "cloud","precip_mm","air_quality", "moon_illumination", "visibility_km", "visibility_miles"]]
weather_repository_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 weather_repository_cleaned=weather_repository_df[["latitude", "longitude", "temperature_fahrenheit", "cloud","precip_mm","air_quality", "moon_illumination", "visibility_km", "visibility_miles"]]
#       2 weather_repository_cleaned.head()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
# ...

# %%
weather_repository_cleaned.to_csv("CSVs/long_lat_temp_wind.csv", index=False)

# %%
weather_repository_cleanclean=weather_repository_df[["country", "location_name", "latitude", "longitude", "temperature_fahrenheit", "cloud","precip_mm","air_quality_PM2.5", "moon_illumination", "visibility_km", "visibility_miles"]]
weather_repository_cleanclean.head()
# Out:
#        country     location_name  latitude  longitude  temperature_fahrenheit  \
# 0  Afghanistan             Kabul     34.52      69.18                    83.8
# 1      Albania            Tirana     41.33      19.82                    80.6
# 2      Algeria           Algiers     36.76       3.05                    82.4
# 3      Andorra  Andorra La Vella     42.50       1.52                    50.4
# 4       Angola            Luanda     -8.84      13.23                    77.0
#
#    cloud  precip_mm  air_quality_PM2.5  moon_illumination  visibility_km  \
# 0      0        0.0                7.9                 93           10.0
# 1     75        0.0               28.2                 93           10.0
# 2     25        0.0                6.4                 93           10.0
# 3      6        0.0                0.5                 93           10.0
# 4     75        0.0              139.6                 93           10.0
#
#    visibility_miles
# 0               6.0
# ...

# %%
weather_repository=weather_repository_cleanclean.rename(columns={"air_quality_PM2.5": "air_quality"})
weather_repository.head()
# Out:
#        country     location_name  latitude  longitude  temperature_fahrenheit  \
# 0  Afghanistan             Kabul     34.52      69.18                    83.8
# 1      Albania            Tirana     41.33      19.82                    80.6
# 2      Algeria           Algiers     36.76       3.05                    82.4
# 3      Andorra  Andorra La Vella     42.50       1.52                    50.4
# 4       Angola            Luanda     -8.84      13.23                    77.0
#
#    cloud  precip_mm  air_quality  moon_illumination  visibility_km  \
# 0      0        0.0          7.9                 93           10.0
# 1     75        0.0         28.2                 93           10.0
# 2     25        0.0          6.4                 93           10.0
# 3      6        0.0          0.5                 93           10.0
# 4     75        0.0        139.6                 93           10.0
#
#    visibility_miles
# 0               6.0
# 1               6.0
# 2               6.0
# ...

# %%
weather_repository.to_csv("CSVs/Weather_Repository.csv", index=False)

# %%
weather = pd.read_csv ("CSVs/Weather_Repository.csv")
weather.to_json ("CSVs/Weather_Repository.json")
